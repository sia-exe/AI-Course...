# %% [markdown]
# <a href="https://colab.research.google.com/github/sia-exe/AI-Course.../blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
place = input("Enter your travel destination: ")
days = int(input("How many days do you want to stay? "))

daily_cost = {
    "dubai": 15000,
    "turkey": 12000,
    "malaysia": 9000
}

print("\n Agent processing...")

if place in daily_cost:
    rate = daily_cost[place]
    total_cost = rate * days

    print("\nAgent: Your estimated trip cost is", total_cost, "PKR")

    if days <= 7:
        print("Agent: This is a short and suitable trip.")
    else:
        print("Agent: This is a long trip. Plan your expenses carefully.")
else:
    print("Agent: Sorry, this destination is not available.")
# Out:
# Enter your travel destination: dubai
# How many days do you want to stay? 3
#
#  Agent processing...
#
# Agent: Your estimated trip cost is 45000 PKR
# Agent: This is a short and suitable trip.
